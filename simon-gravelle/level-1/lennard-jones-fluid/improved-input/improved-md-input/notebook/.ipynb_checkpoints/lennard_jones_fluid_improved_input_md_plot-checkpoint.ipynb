# %%
import numpy
from numpy import ndarray
from typing import List
from matplotlib.legend import Legend
from matplotlib import pyplot as pyplot

# %% [markdown]
# # Extract timestep and atom type 1 & 2 cylinder population from atom population .dat files

# %%
# File contains columns of data, the .T transpose operation switches them to rows, making it easier to
# unpack into separate variables
time, atom_type_1_pop_inside_cylinder = numpy.loadtxt(
    '../data/raw/atom-population/output_atom_type_1_population_inside_cylinder_vs_time.dat'
).T

# Subtracts the first element from every element in the time array, ensuring the first element is 0/the time starts
# at zero
time -= time[0]

# Multiply each element by the timestep value
time *= 0.005

# The `_` name is a conventional placeholder for a variable that is to be ignored. We ignore the time data as we
# have already unpacked it
_, atom_type_2_pop_inside_cylinder = numpy.loadtxt(
    '../data/raw/atom-population/output_atom_type_2_population_inside_cylinder_vs_time.dat'
).T

# Combine time, atom type 1 & atom type 2 data into two separate ndarrays
atom_population_vs_time_data_array: List[ndarray] = [
    numpy.vstack((time, atom_type_1_pop_inside_cylinder)),
    numpy.vstack((time, atom_type_2_pop_inside_cylinder))
]

# %% [markdown]
# # Create Matplotlib graph to plot atom type 1 & type 2 cylinder population vs time

# %%
# Set up the line graph
atom_pop_vs_time_line_graph_figure, atom_pop_vs_time_line_graph_axes = pyplot.subplots(figsize=(18, 10))
atom_pop_vs_time_line_graph_figure.patch.set_facecolor('black')
atom_pop_vs_time_line_graph_axes.set_facecolor('black')

# Stylise ticks and spines
atom_pop_vs_time_line_graph_axes.tick_params(colors='white', which='both', labelsize=20)
for spine in atom_pop_vs_time_line_graph_axes.spines.values():
    spine.set_edgecolor('white')

# Plot the data
atom_pop_vs_time_line_graph_axes.plot(time, atom_type_1_pop_inside_cylinder, color='orange', 
                                linewidth=3.5, label='Atom Type 1 Population Inside Cylinder')
atom_pop_vs_time_line_graph_axes.plot(time, atom_type_2_pop_inside_cylinder, color='cyan', 
                                linewidth=3.5, label='Atom Type 2 Population Inside Cylinder')

# Set axes labels, limits and graph title
atom_pop_vs_time_line_graph_axes.set_xlabel(r'$t$', color='white', fontsize=20)
atom_pop_vs_time_line_graph_axes.set_ylabel(r'$N(inside)$', color='white', fontsize=20)
atom_pop_vs_time_line_graph_axes.set_xlim(0, 1500)
atom_pop_vs_time_line_graph_axes.set_ylim(0, 225)
atom_pop_vs_time_line_graph_axes.set_title(r'$\bf{Atom\ Type\ 1\ &\ Atom\ Type\ 2\ Population\ Inside\ Cylinder\ vs\ Time}$', 
                                     fontsize=17.5, color='white')

# Add legend
atom_pop_vs_time_legend: Legend = atom_pop_vs_time_line_graph_axes.legend(loc='upper right', frameon=False, fontsize=15)
for text in atom_pop_vs_time_legend.get_texts():
    text.set_color('white')

# Add figure title
atom_pop_vs_time_line_graph_figure.text(0.5, 0.0005,
                r'$\bf{Fig\ 1}$ Evolution of number of atoms within the `$region\_inside\_cylinder$` region as a '
                r'function of time',
                ha='center', va='center', color='white', fontsize=17.5)

# Save & display the plot
pyplot.savefig('../reports/figures/graphs/atom_type_1_2_cylinder_population_vs_time.png', bbox_inches='tight')
pyplot.show()

# %% [markdown]
# # Extract atom type 1 coordination number data from `output_average_atom_type_1_coordination_number.dat`

# %%
# Unpack coordination number data. Again, time data is ignored as it has already been unpacked
_, atom_type_1_coordination_number = numpy.loadtxt(
    '../data/raw/atom-coordination-number/output_average_atom_type_1_coordination_number.dat'
).T

# Combine time and atom coordination number data into ndarray
atom_coordination_number_vs_time_data_array: List[ndarray] = [
    numpy.vstack((time, atom_type_1_coordination_number))
]

# %% [markdown]
# # Create Matplotlib graph to plot atom type 1 coordination number vs time

# %%
# Set up the line graph
atom_coord_vs_time_line_graph_figure, atom_coord_vs_time_line_graph_axes = pyplot.subplots(figsize=(18, 10))
atom_coord_vs_time_line_graph_figure.patch.set_facecolor('black')
atom_coord_vs_time_line_graph_axes.set_facecolor('black')

# Stylise ticks and spines
atom_coord_vs_time_line_graph_axes.tick_params(colors='white', which='both', labelsize=20)
for spine in atom_coord_vs_time_line_graph_axes.spines.values():
    spine.set_edgecolor('white')

# Plot the data
atom_coord_vs_time_line_graph_axes.plot(time, atom_type_1_coordination_number, color='cyan', 
                                linewidth=3.5)

# Set axes labels, limits and graph title
atom_coord_vs_time_line_graph_axes.set_xlabel(r'$t$', color='white', fontsize=20)
atom_coord_vs_time_line_graph_axes.set_ylabel(r'$Coordination\ Number$', color='white', fontsize=20)
atom_coord_vs_time_line_graph_axes.set_xlim(0, 1500)
atom_coord_vs_time_line_graph_axes.set_ylim(0.00, 0.05)
atom_coord_vs_time_line_graph_axes.set_title(r'$\bf{Atom\ Type\ 1\ Coordination\ Number\ vs\ Time}$', 
                                     fontsize=20, color='white')

# Add figure title
atom_coord_vs_time_line_graph_figure.text(0.5, 0.0005,
                r'$\bf{Fig\ 2}$ Evolution of atom type 1 coordination number within the `$region\_cylinder\_in$` '
                r'region as a function of time',
                ha='center', va='center', color='white', fontsize=17.5)

# Save & display the plot
pyplot.savefig('../reports/figures/graphs/atom_type_1_coordination_vs_time.png', bbox_inches='tight')
pyplot.show()
